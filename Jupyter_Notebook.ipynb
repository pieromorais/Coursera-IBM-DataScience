# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <strong>Piero Silva Morais</strong>
# <br>
# Data Analyst

# %% [markdown]
# <i>I am interested in data science because can help me make preditions about oil market, for example.</i>
# <br>
# <i>Data Science enables a whole new level of data manipulation and extraction of value. I want to incorporate these tools to my arsenal as a Data Geek.</i>

# %% [markdown]
# <h3>Use PI² to approximate gravity acceleration</h3>

# %%
PI = 3.14
g = 3.14**2
g
# Out:
# 9.8596

# %% [markdown]
# |Header|Header|
# |------|------|
# |Cell|Cell|
#
# <ul>
# <li>First Bullet</li>
# <li>Second Bullet</li>
# </ul>
#
# <ol>
# <li>First Item</li>
# <li>Second Item</li>
# </ol>
